# %% [markdown]
# # Booleans
#
# bool - True, False, None
#
# Python is built in with True and False values called Booleans.

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
a = True

# %%
a
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 == 2
# Out:
# False

# %%
b = None

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False
